# %%
print("python")
# Out:
# python

# %%
# comment
print("Hello python")
# Out:
# Hello python

# %%
# comment

"""
hello
python
"""
# Out:
# '\nhello\npython\n'

# %%
# comment
print("jupyter")

"""
hello
jupyter
"""
# Out:
# jupyter
# '\nhello\njupyter\n'

# %%
"""
Data
Science
"""
# Out:
# '\nData\nScience\n'

# %%
# legal variable name:
myvar = "watch"
my_var = "watch"
_my_var = "watch"
MYVAR = "watch"
myvar2 = "watch"

# %%
# Illegal variable name:
2myvar = "watch"
# Out:
#   File "<ipython-input-31-5527c8eb279c>", line 2
#     2myvar = "watch"
#      ^
# SyntaxError: invalid syntax

# %%
myvar = "watch"

# %%
my-var = "watch"
# Out:
#   File "<ipython-input-33-16b8710124dc>", line 1
#     my-var = "watch"
#     ^
# SyntaxError: cannot assign to operator

# %%
a = 1
print(a)
# Out:
# 1

# %%
# integer
print(a,type(a))
# Out:
# 1 <class 'int'>

# %%
a = 2.5
print(a)
# Out:
# 2.5

# %%
a = 2.5
print(a,type(a))
# Out:
# 2.5 <class 'float'>

# %%
# float
print(a,type(a))
# Out:
# 2.5 <class 'float'>

# %%
# float
a = 2.5
print(a)
print(type (a))
# Out:
# 2.5
# <class 'float'>

# %%
# float
a = 2.5
print(type(a))
print(a)
# Out:
# <class 'float'>
# 2.5

# %%
a = '''python assignment'''
print(a,type(a))
# Out:
# python assignment <class 'str'>

# %%
a = """python
assignment"""
print(a)
# Out:
# python
# assignment

# %%
a = """python
assignment"""
print(a,type(a))
# Out:
# python
# assignment <class 'str'>

# %%
print(11 < 10)
print(11 == 11)
print(11 > 10)
# Out:
# False
# True
# True

# %%
print(-11 > -12)
print(11 == 10)
print(-11 < 10)
# Out:
# True
# False
# True

# %%
x = int(1)
x
# Out:
# 1

# %%
x = int(1.2)
x
# Out:
# 1

# %%
y = float(2.4)
y
# Out:
# 2.4

# %%
y = float(2)
y
# Out:
# 2.0

# %%
x = float("1.2")
y = float("2.4")
z = int("1")
print(x,y,z)
# Out:
# 1.2 2.4 1

# %%
x = str("tom")
y = str("1")
z = str("2.7")
print(x,y,z)
# Out:
# tom 1 2.7

# %%
# Addition
20+10
# Out:
# 30

# %%
# subtraction
20-10
# Out:
# 10

# %%
# Multiplication
2*10
# Out:
# 20

# %%
# Division
3/4
# Out:
# 0.75

# %%
# modulus
20 % 10000
# Out:
# 20

# %%
# floor Division
35 // 4
# Out:
# 8

# %%
# exponentiation
24 ** 4
# Out:
# 331776

# %%
x = 10

# %%
x += 5
x
# Out:
# 15

# %%
x -= 5
x
# Out:
# 10

# %%
x *= 5
x
# Out:
# 50

# %%
x = x-5
x
# Out:
# 45

# %%
x = x / 5
x
# Out:
# 9.0

# %%
x %= 5
x
# Out:
# 4.0

# %%
x = 5

# %%
# x //= 3
x = x // 3
x
# Out:
# 1

# %%
# x **= 7
x = x ** 7
x
# Out:
# 1

# %%
x = 1

# %%
# x &= 0
x = x & 0
x
# Out:
# 0

# %%
8|5
# Out:
# 13

# %%
8&5
# Out:
# 0

# %%
a = 4
b = 5

(a<3)|(b>6)
# Out:
# False

# %%
x = 28

# %%
# x |= 2
x = x | 2
x
# Out:
# 30

# %%
x = 7
y = 4

# %%
# Equal
x == y
# Out:
# False

# %%
# not equal
x != y
# Out:
# True

# %%
# greater than
x > y
# Out:
# True

# %%
# less than
y < x
# Out:
# True

# %%
# greater than equal to
x >= y
# Out:
# True

# %%
# less than equal to
x <= y
# Out:
# False

# %%
a = 3

# %%
List_1 = ["jupyter","python",a]
List_1
# Out:
# ['jupyter', 'python', 3]

# %%
type(List_1)
# Out:
# list

# %%
len(List_1)
# Out:
# 3

# %%
List_1[2]
# Out:
# 3

# %%
List_1.append('e')
List_1
# Out:
# ['jupyter', 'python', 3, 'e']

# %%
List_2 = list(range(5,50,7))
List_2
# Out:
# [5, 12, 19, 26, 33, 40, 47]

# %%
List_1.extend(List_2)
List_1
# Out:
# ['jupyter', 'python', 3, 'e', 5, 12, 19, 26, 33, 40, 47]

# %%
List_3 = [x-10 for x in List_2 if type(x)==int]
List_3
# Out:
# [-5, 2, 9, 16, 23, 30, 37]

# %%
# %%timeit
[x**2 for x in List_2 if type(x)==int]
# Out:
# 5.8 µs ± 248 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
[x/2 for x in range(50,5000,500) if x<=1000]
# Out:
# [25.0, 275.0]

# %%
set_1 = {"yellow","violet","purple","violet"}
set_1
# Out:
# {'purple', 'violet', 'yellow'}

# %%
Tuple_1 = (1.2,2,3)
Tuple_1
# Out:
# (1.2, 2, 3)

# %%
List_1 = [1.2,2,3]
List_1
# Out:
# [1.2, 2, 3]

# %%
print(List_1*5)
print(Tuple_1*5)
# Out:
# [1.2, 2, 3, 1.2, 2, 3, 1.2, 2, 3, 1.2, 2, 3, 1.2, 2, 3]
# (1.2, 2, 3, 1.2, 2, 3, 1.2, 2, 3, 1.2, 2, 3, 1.2, 2, 3)

# %%
print(['a']+List_1[:2]+[6]+List_1[3:])
# Out:
# ['a', 1.2, 2, 6]

# %%
print((6,)+Tuple_1)
# Out:
# (6, 1.2, 2, 3)

# %%
print((6,)+List_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-220-f8d6f8da29e8> in <module>
# ----> 1 print((6,)+List_1)
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
Dict_1 = {'A':1,'B':5,'c':6}

# %%
Dict_1['B']
# Out:
# 5

# %%
import pandas as pd
df = pd.DataFrame([{'A':5,'B':6,'C':7}])
df.loc[1,'A'] = 5
df.loc[2,'B'] = 4
df.loc[3,'C'] = 2
df
# Out:
#      A    B    C
# 0  5.0  6.0  7.0
# 1  5.0  NaN  NaN
# 2  NaN  4.0  NaN
# 3  NaN  NaN  2.0

# %%
import numpy as np
np.array(df['A'])
np.array(df['B'])
np.array(df['C'])
# Out:
# array([ 7., nan, nan,  2.])

# %%
a = int(input("Enter the value : "))
# Out:
# Enter the value : 6

# %%
if a > 5: print(a+3)
else: print(a)
# Out:
# 9

# %%
if (a<7)&(a>5): print(a+1)
elif (a==9)&(a<8): print(a+3)  
else: print(a)
# Out:
# 7

# %%
if (a<8)&(a>4): print(a+1)
if (a==6): print(a+2)
else: print(a)
# Out:
# 7
# 8

# %%
# %%timeit
a = 10
while a > 5:
    a -= 2
    print(a)
# Out:
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# 6
# 4
# 8
# ...

# %%
# %%timeit
a = 10
for i in range(20,20000):
    a -= 2
    print(a)
    if a <= 8: break
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# ...

# %%
def area(a,b):
    c = a+b
    return a,b,c

area(10,15)
# Out:
# (10, 15, 25)

# %%
# file1.py

class class1():
    a = 5.2

# %%
# file2.py

# import file1

class1.a
# Out:
# 5.2

# %%
x = 10

# %%
x = 10
# 1010

# x >>= 2
x = x >> 2
x
# Out:
# 2

# %%
x = 10
# 1010

# x << 2
x = x << 2
x
# Out:
# 40
